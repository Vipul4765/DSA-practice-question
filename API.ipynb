# %% [markdown]
# <a href="https://colab.research.google.com/github/Vipul4765/DSA-practice-question/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
balls = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022 - IPL_Ball_by_Ball_2008_2022.csv')

# %%
matches = pd.read_csv('/content/ipl-matches.csv')

# %%
iplball_matches = matches.merge(balls,how = 'inner', on = 'ID')

# %%
iplball_matches.head(2)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... extra_type batsman_run extras_run  total_run non_boundary  \
# 0          bat  ...        NaN           0          0          0            0
# 1          bat  ...    legbyes           0          1          1            0
#
#   isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                0        NaN  NaN               NaN  Rajasthan Royals
# 1                0        NaN  NaN               NaN  Rajasthan Royals
#
# [2 rows x 36 columns]

# %%
iplball_matches.groupby('ID')

# %%
balls['isWicketDelivery'].value_counts()
# Out:
# 0    214803
# 1     11151
# Name: isWicketDelivery, dtype: int64

# %%
(balls[balls['batter']== 'V Kohli'])['isWicketDelivery'].sum()
# Out:
# 193

# %%
df = balls[balls['batter']== 'V Kohli'].groupby('ID').sum()
# Out:
# <ipython-input-238-931320e83388>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = balls[balls['batter']== 'V Kohli'].groupby('ID').sum()

# %%
import pandas as pd

# Assuming 'balls' is your DataFrame and you've already filtered for 'V Kohli'
filtered_data = balls[balls['batter'] == 'V Kohli']
number_of_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()

iplball_matches['Season'].nunique()
filtered_data['ID'].nunique()
# Out:
# <ipython-input-239-41ab63c6b6f1>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   number_of_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()
# 215

# %%
19000 * 20 * 6
# Out:
# 2280000

# %%
2280000 - 596989
# Out:
# 1683011

# %%
def batsman_record_dict(playername):
    """
    Return the batting record of a player in the form of a dictionary.

    Args:
        playername (str): The name of the player.

    Returns:
        dict: The batting record of the player.
    """

    filtered_data = balls[balls['batter'] == playername]

    """
    Number of centuries scored by the player.
    """
    century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()

    """
    Number of half-centuries scored by the player.
    """
    half_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 50).sum() - century

    """
    Total runs scored by the player.
    """
    total_runs = filtered_data['batsman_run'].sum()

    """
    Total balls faced by the player.
    """
    total_balls = filtered_data.shape[0]

    """
    Strike rate of the player.
    """
    strike_rate = total_runs / total_balls

    """
    Number of fours hit by the player.
    """
    four = (filtered_data['batsman_run'] == 4).sum()

    """
    Number of sixes hit by the player.
    """
    six = (filtered_data['batsman_run'] == 6).sum()

    """
    Number of times the player got out.
    """
    out = filtered_data['isWicketDelivery'].sum()

    """
    Average score of the player.
    """
    average = total_runs / out

    """
    total_season
    """
    total_season = matches['Season'].nunique()

    """
    total number of matches
    """
    total_matches = filtered_data['ID'].nunique()

    """
    highest Score
    """
    highest_score = filtered_data.groupby('ID').sum()['batsman_run'].max()

    """
    ALL Season Runs
    """
    iplball_matches = matches.merge(balls,how = 'inner', on = 'ID')
    player_runs_per_season = iplball_matches[iplball_matches['batter'] == player_name].groupby('Season')['batsman_run'].sum()

    return {
        'Player name' : playername,
        'total Season' : total_season,
        'total matches' : total_matches,
        'century': century,
        'half_century': half_century,
        'total_runs': total_runs,
        'total_balls': total_balls,
        'strike_rate': strike_rate,
        'four': four,
        'six': six,
        'out': out,
        'average': average,
        #'matches': matches,
        'highest score' : highest_score,
        'All season runs' : player_runs_per_season
    }

# %%
batsman_record_dict('V Kohli')
# Out:
# <ipython-input-258-528714558ac2>:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()
# <ipython-input-258-528714558ac2>:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   half_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 50).sum() - century
# <ipython-input-258-528714558ac2>:72: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
total_runs = balls[balls['batter']== 'V Kohli'].sum()['batsman_run']
# Out:
# <ipython-input-244-fd1fc3863565>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   total_runs = balls[balls['batter']== 'V Kohli'].sum()['batsman_run']

# %%
total_runs
# Out:
# 6634

# %%
balls.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN          0.0         0.0        0.0           0.0
# 1   JC Buttler    legbyes          0.0         1.0        1.0           0.0
# 2  YBK Jaiswal        NaN          1.0         0.0        1.0           0.0
# 3   JC Buttler        NaN          0.0         0.0        0.0           0.0
# 4   JC Buttler        NaN          0.0         0.0        0.0           0.0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
iplball_matches = matches.merge(balls,how = 'inner', on = 'ID')
iplball_matches.groupby('Season')

# %%
player_name = 'V Kohli'
iplball_matches = matches.merge(balls,how = 'inner', on = 'ID')
player_runs_per_season = iplball_matches[iplball_matches['batter'] == player_name].groupby('Season')['batsman_run'].sum()
player_runs_per_season
# Out:
# Season
# 2007/08    165
# 2009       246
# 2009/10    307
# 2011       557
# 2012       364
# 2013       639
# 2014       359
# 2015       505
# 2016       973
# 2017       308
# 2018       530
# 2019       464
# 2020/21    471
# 2021       405
# 2022       341
# Name: batsman_run, dtype: int64

# %%
iplball_matches.head(5)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 2  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 3  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 4  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 2  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 4  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... extra_type batsman_run extras_run  total_run non_boundary  \
# ...

# %%
def max_runs_in_season(playername):
    """
    Return the maximum runs scored by a batsman in a single season.

    Args:
        playername (str): The name of the player.

    Returns:
        int: The maximum runs scored by the player in a single season.
    """

    filtered_data = balls[balls['batter'] == playername]

    """
    Create a dictionary to store the maximum runs scored by the player in each season.
    """
    max_runs_per_season = {}

    """
    Iterate over the years.
    """
    for year in filtered_data['Season'].unique():
        season_data = filtered_data[filtered_data['Season'] == year]

        """
        Calculate the runs scored by the player in the current season.
        """
        runs_in_season = season_data['batsman_run'].sum()

        """
        Update the maximum runs if the runs scored in the current season is more than the maximum runs scored so far.
        """
        if runs_in_season > max_runs_per_season['runs']:
            max_runs_per_season['runs'] = runs_in_season
            max_runs_per_season['year'] = year

    return max_runs_per_season['runs']

# %%
max_runs_in_season('V Kohli')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Season'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
balls.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
total_season = matches['Season'].nunique()

# %%
total_season
# Out:
# 15

# %%
import pandas as pd
import numpy as np
import json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

matches = pd.read_csv('ipl-matches.csv')
balls = pd.read_csv('IPL_Ball_by_Ball_2008_2022 - IPL_Ball_by_Ball_2008_2022.csv')
balls_matches = pd.merge(matches, balls, on='ID', how='inner')

def all_ipl_batsman():
    seasonwise_batsman = {}
    all_batsman = list(set(balls['batter']))
    season = list(matches['Season'].unique())
    for i in season:
        filtered_data = balls_matches.loc[balls_matches['Season'] == i]
        seasonwise_batsman[i] = list((filtered_data['batter'].unique()))
    result = {
        'total': len(all_batsman),
        'all_batsman_ipl': all_batsman,
        'seasons': season,
        'seasonwise_batsmen': seasonwise_batsman
    }
    return json.dumps(result, cls=NpEncoder)

def batsman_record(playername):
    all_batsman = list(set(balls['batter']))
    if playername in all_batsman:
        filtered_data = balls[balls['batter'] == playername]
        century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()
        half_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 50).sum() - century
        total_runs = filtered_data['batsman_run'].sum()
        total_balls = filtered_data.shape[0]
        strike_rate = total_runs / total_balls
        four = (filtered_data['batsman_run'] == 4).sum()
        six = (filtered_data['batsman_run'] == 6).sum()
        out = filtered_data['isWicketDelivery'].sum()
        average = total_runs / out
        total_season = matches['Season'].nunique()
        total_matches = filtered_data['ID'].nunique()
        highest_score = filtered_data.groupby('ID').sum()['batsman_run'].max()
        iplball_matches = matches.merge(balls, how='inner', on='ID')
        player_runs_per_season = iplball_matches[iplball_matches['batter'] == playername].groupby('Season')[
            'batsman_run'].sum()
        result = {
            'Player name': playername,
            'total Season': total_season,
            'total matches': total_matches,
            'century': century,
            'half_century': half_century,
            'total_runs': total_runs,
            'total_balls': total_balls,
            'strike_rate': strike_rate,
            'four': four,
            'six': six,
            'out': out,
            'average': average,
            'highest score': highest_score,
            'All season runs': player_runs_per_season
        }
        return json.dumps(result, cls=NpEncoder)
    return {'message': 'invalid player name'}

# %%
def batsman_record(playername):
    all_batsman = list(set(balls['batter']))
    if playername in all_batsman:
        filtered_data = balls[balls['batter'] == playername]
        century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()
        half_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 50).sum() - century
        total_runs = filtered_data['batsman_run'].sum()
        total_balls = filtered_data.shape[0]
        strike_rate = total_runs / total_balls
        four = (filtered_data['batsman_run'] == 4).sum()
        six = (filtered_data['batsman_run'] == 6).sum()
        out = filtered_data['isWicketDelivery'].sum()
        average = total_runs / out
        total_season = matches['Season'].nunique()
        total_matches = filtered_data['ID'].nunique()
        highest_score = filtered_data.groupby('ID').sum()['batsman_run'].max()
        iplball_matches = matches.merge(balls, how='inner', on='ID')
        player_runs_per_season = iplball_matches[iplball_matches['batter'] == playername].groupby('Season')[
            'batsman_run'].sum()
        player_runs_per_season_list = dict(player_runs_per_season)
        result = {
            'Player name': playername,
            'total Season': int(total_season),  # Convert to int
            'total matches': int(total_matches),  # Convert to int
            'century': int(century),  # Convert to int
            'half_century': int(half_century),  # Convert to int
            'total_runs': int(total_runs),  # Convert to int
            'total_balls': int(total_balls),  # Convert to int
            'strike_rate': float(strike_rate),  # Convert to float
            'four': int(four),  # Convert to int
            'six': int(six),  # Convert to int
            'out': int(out),  # Convert to int
            'average': float(average),  # Convert to float
            'highest score': int(highest_score),  # Convert to int
            'All season runs': player_runs_per_season_list  # Use the converted list
        }
        return result

# %%
batsman_record('V Kohli')
# Out:
# <ipython-input-267-93f60cd9f5f3>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 100).sum()
# <ipython-input-267-93f60cd9f5f3>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   half_century = (filtered_data.groupby('ID').sum()['batsman_run'] >= 50).sum() - century
# <ipython-input-267-93f60cd9f5f3>:16: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %%
batsmen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-271-73eef82a8991> in <cell line: 1>()
# ----> 1 batsmen
#
# NameError: name 'batsmen' is not defined

# %%
matches.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
balls.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
team_condition = iplball_matches[(iplball_matches['Team1'] == 'Royal Challengers Bangalore') | (iplball_matches['Team2'] == 'Royal Challengers Bangalore')
# Out:
#   File "<ipython-input-308-b7f994c6e9ea>", line 1
#     team_condition = iplball_matches[(iplball_matches['Team1'] == 'Royal Challengers Bangalore') | (iplball_matches['Team2'] == 'Royal Challengers Bangalore')
#                                                                                                                                                               ^
# SyntaxError: incomplete input

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-305-d4fee8e929a5> in <cell line: 1>()
# ----> 1 df.groupby('batter')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     985             return self[attr]
#     986
# --> 987         raise AttributeError(
#     988             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
df = iplball_matches.groupby('Team1') or iplball_matches.groupby('Team2')

# %%
df = iplball_matches[iplball_matches['batter'] == 'V Kohli']
df.groupby(['Team1','Team2'])['batsman_run'].sum()

# %%
df.groupby(['Team1','Team2'])['batsman_run'].sum()
# Out:
# Team1                        Team2
# Chennai Super Kings          Royal Challengers Bangalore    325
# Deccan Chargers              Royal Challengers Bangalore    125
# Delhi Capitals               Royal Challengers Bangalore     70
# Delhi Daredevils             Royal Challengers Bangalore    538
# Gujarat Lions                Royal Challengers Bangalore    164
# Gujarat Titans               Royal Challengers Bangalore     73
# Kings XI Punjab              Royal Challengers Bangalore    272
# Kochi Tuskers Kerala         Royal Challengers Bangalore     23
# Kolkata Knight Riders        Royal Challengers Bangalore    223
# Mumbai Indians               Royal Challengers Bangalore    466
# Pune Warriors                Royal Challengers Bangalore     34
# Punjab Kings                 Royal Challengers Bangalore     55
# Rajasthan Royals             Royal Challengers Bangalore    474
# Rising Pune Supergiant       Royal Challengers Bangalore     55
# ...

# %%
df.groupby(['Team1','Team2'])['batsman_run'].sum()
# Out:
# Team1                        Team2
# Chennai Super Kings          Royal Challengers Bangalore    325
# Deccan Chargers              Royal Challengers Bangalore    125
# Delhi Capitals               Royal Challengers Bangalore     70
# Delhi Daredevils             Royal Challengers Bangalore    538
# Gujarat Lions                Royal Challengers Bangalore    164
# Gujarat Titans               Royal Challengers Bangalore     73
# Kings XI Punjab              Royal Challengers Bangalore    272
# Kochi Tuskers Kerala         Royal Challengers Bangalore     23
# Kolkata Knight Riders        Royal Challengers Bangalore    223
# Mumbai Indians               Royal Challengers Bangalore    466
# Pune Warriors                Royal Challengers Bangalore     34
# Punjab Kings                 Royal Challengers Bangalore     55
# Rajasthan Royals             Royal Challengers Bangalore    474
# Rising Pune Supergiant       Royal Challengers Bangalore     55
# ...

# %%
df = iplball_matches[iplball_matches['batter'] == 'V Kohli']
var = df['Team1'] +','+ df['Team2']

# %%
record_against_all_teams('V Kholi')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'batting_team'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd

# Assuming you have already merged matches and balls into iplball_matches
# iplball_matches = matches.merge(balls, how='inner', on='ID')

# Filter the DataFrame for matches where 'V Kohli' played
df = iplball_matches[iplball_matches['batter'] == 'V Kohli']

# Group by combinations of 'Team1' and 'Team2' and calculate the sum of 'batsman_run'
sum_batsman_run_per_team1 = df.groupby(['Team1'])['batsman_run'].sum().reset_index()

# %%
sum_batsman_run_per_team1 = df.groupby(['Team1'])['batsman_run'].sum()

# %%
sum_batsman_run_per_team2 = df.groupby(['Team2'])['batsman_run'].sum()

# %%
sum_batsman_run_per_team1 + sum_batsman_run_per_team2
# Out:
# Team2
# Chennai Super Kings             654
# Deccan Chargers                 181
# Delhi Capitals                   94
# Delhi Daredevils                223
# Gujarat Lions                   119
# Gujarat Titans                   58
# Kings XI Punjab                 409
# Kochi Tuskers Kerala             27
# Kolkata Knight Riders           563
# Lucknow Super Giants             25
# Mumbai Indians                  308
# Pune Warriors                    94
# Punjab Kings                     66
# Rajasthan Royals                126
# Rising Pune Supergiant           28
# Rising Pune Supergiants         108
# Royal Challengers Bangalore    3216
# Sunrisers Hyderabad             335
# Name: batsman_run, dtype: int64

# %%
sum_batsman_run_per_team1 + sum_batsman_run_per_team2
# Out:
# Chennai Super Kings             979.0
# Deccan Chargers                 306.0
# Delhi Capitals                  164.0
# Delhi Daredevils                761.0
# Gujarat Lions                   283.0
# Gujarat Titans                  131.0
# Kings XI Punjab                 681.0
# Kochi Tuskers Kerala             50.0
# Kolkata Knight Riders           786.0
# Lucknow Super Giants              NaN
# Mumbai Indians                  774.0
# Pune Warriors                   128.0
# Punjab Kings                    121.0
# Rajasthan Royals                600.0
# Rising Pune Supergiant           83.0
# Rising Pune Supergiants         188.0
# Royal Challengers Bangalore    6634.0
# Sunrisers Hyderabad             574.0
# Name: batsman_run, dtype: float64

# %%
sum_batsman_run_per_team1
# Out:
# Team1
# Chennai Super Kings             325
# Deccan Chargers                 125
# Delhi Capitals                   70
# Delhi Daredevils                538
# Gujarat Lions                   164
# Gujarat Titans                   73
# Kings XI Punjab                 272
# Kochi Tuskers Kerala             23
# Kolkata Knight Riders           223
# Mumbai Indians                  466
# Pune Warriors                    34
# Punjab Kings                     55
# Rajasthan Royals                474
# Rising Pune Supergiant           55
# Rising Pune Supergiants          80
# Royal Challengers Bangalore    3418
# Sunrisers Hyderabad             239
# Name: batsman_run, dtype: int64

# %%
merged_df
# Out:
#                           Team1  batsman_run_x                        Team2  \
# 0           Chennai Super Kings            325          Chennai Super Kings
# 1               Deccan Chargers            125              Deccan Chargers
# 2                Delhi Capitals             70               Delhi Capitals
# 3              Delhi Daredevils            538             Delhi Daredevils
# 4                 Gujarat Lions            164                Gujarat Lions
# 5                Gujarat Titans             73               Gujarat Titans
# 6               Kings XI Punjab            272              Kings XI Punjab
# 7          Kochi Tuskers Kerala             23         Kochi Tuskers Kerala
# 8         Kolkata Knight Riders            223        Kolkata Knight Riders
# 9                Mumbai Indians            466               Mumbai Indians
# 10                Pune Warriors             34                Pune Warriors
# ...

# %%
merged_df = pd.merge(sum_batsman_run_per_team1, sum_batsman_run_per_team2,
                     how='inner', left_on='Team1', right_on='Team2')

print(merged_df)
# Out:
#                           Team1  batsman_run_x                        Team2  \
# 0           Chennai Super Kings            325          Chennai Super Kings
# 1               Deccan Chargers            125              Deccan Chargers
# 2                Delhi Capitals             70               Delhi Capitals
# 3              Delhi Daredevils            538             Delhi Daredevils
# 4                 Gujarat Lions            164                Gujarat Lions
# 5                Gujarat Titans             73               Gujarat Titans
# 6               Kings XI Punjab            272              Kings XI Punjab
# 7          Kochi Tuskers Kerala             23         Kochi Tuskers Kerala
# 8         Kolkata Knight Riders            223        Kolkata Knight Riders
# 9                Mumbai Indians            466               Mumbai Indians
# 10                Pune Warriors             34                Pune Warriors
# ...

# %%
import pandas as pd

def calculate_total_runs_per_team(df):
    # Calculate the sum of runs for each team using groupby
    sum_batsman_run_per_team1 = df.groupby(['Team1'])['batsman_run'].sum()
    sum_batsman_run_per_team2 = df.groupby(['Team2'])['batsman_run'].sum()

    # Combine the sums from both groups
    total_runs_per_team = sum_batsman_run_per_team1 + sum_batsman_run_per_team2

    return total_runs_per_team

# Assuming you have a DataFrame named 'df'
# df = ...

# Call the function and print the result
total_runs_per_team = calculate_total_runs_per_team(df)
print(total_runs_per_team)
# Out:
# Chennai Super Kings             979.0
# Deccan Chargers                 306.0
# Delhi Capitals                  164.0
# Delhi Daredevils                761.0
# Gujarat Lions                   283.0
# Gujarat Titans                  131.0
# Kings XI Punjab                 681.0
# Kochi Tuskers Kerala             50.0
# Kolkata Knight Riders           786.0
# Lucknow Super Giants              NaN
# Mumbai Indians                  774.0
# Pune Warriors                   128.0
# Punjab Kings                    121.0
# Rajasthan Royals                600.0
# Rising Pune Supergiant           83.0
# Rising Pune Supergiants         188.0
# Royal Challengers Bangalore    6634.0
# Sunrisers Hyderabad             574.0
# Name: batsman_run, dtype: float64

# %%
import pandas as pd
import numpy as np
import json

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

def batsmanRecord(batsman, df):
    if df.empty:
        return np.nan
    out = df[df.player_out == batsman].shape[0]
    df = df[df['batter'] == batsman]
    inngs = df.ID.nunique()
    runs = df.batsman_run.sum()
    fours = df[(df.batsman_run == 4) & (df.non_boundary == 0)].shape[0]
    sixes = df[(df.batsman_run == 6) & (df.non_boundary == 0)].shape[0]
    if out:
        avg = runs / out
    else:
        avg = np.inf

    nballs = df[~(df.extra_type == 'wides')].shape[0]
    if nballs:
        strike_rate = runs / nballs * 100
    else:
        strike_rate = 0
    gb = df.groupby('ID').sum()
    fifties = gb[(gb.batsman_run >= 50) & (gb.batsman_run < 100)].shape[0]
    hundreds = gb[gb.batsman_run >= 100].shape[0]
    try:
        highest_score = gb.batsman_run.max()
        hsindex = gb.batsman_run.idxmax()
        if (df[df.ID == hsindex].player_out == batsman).any():
            highest_score = str(highest_score)
        else:
            highest_score = str(highest_score) + '*'
    except:
        highest_score = gb.batsman_run.max()

    not_out = inngs - out
    mom = df[df.Player_of_the_Match == batsman].drop_duplicates('ID', keep='first').shape[0]
    data = {
        'innings': inngs,
        'runs': runs,
        'fours': fours,
        'sixes': sixes,
        'avg': avg,
        'strikeRate': strike_rate,
        'fifties': fifties,
        'hundreds': hundreds,
        'highestScore': highest_score,
        'notOut': not_out,
        'mom': mom
    }

    return data

def batsmanVsTeam(batsman, team, df):
    df = df[df.Team2 == team].copy()
    return batsmanRecord(batsman, df)

def batsmanAPI(batsman, balls=batter_data):
    df = balls[balls.innings.isin([1, 2])]  # Excluding Super overs
    self_record = batsmanRecord(batsman, df=df)
    TEAMS = matches.Team1.unique()
    against = {team: batsmanVsTeam(batsman, team, df) for team in TEAMS}
    data = {
        batsman: {'all': self_record,
                  'against': against}
    }
    return json.dumps(data, cls=NpEncoder)

# Modify bowler_data according to your previous data
bowler_data = iplball_matches.copy()

# Call the function and print the result for a specific batsman
batsman_name = 'V Kohli'  # Replace with the desired batsman's name
result = batsmanAPI(batsman_name, balls=bowler_data)
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-360-a778e9e12408> in <cell line: 69>()
#      67     return batsmanRecord(batsman, df)
#      68
# ---> 69 def batsmanAPI(batsman, balls=batter_data):
#      70     df = balls[balls.innings.isin([1, 2])]  # Excluding Super overs
#      71     self_record = batsmanRecord(batsman, df=df)
#
# NameError: name 'batter_data' is not defined

# %%
def batsmanRecord(batsman, df):
    if df.empty:
        return np.nan
    out = df[df.player_out == batsman].shape[0]
    df = df[df['batter'] == batsman]
    inngs = df.ID.nunique()
    runs = df.batsman_run.sum()
    fours = df[(df.batsman_run == 4) & (df.non_boundary == 0)].shape[0]
    sixes = df[(df.batsman_run == 6) & (df.non_boundary == 0)].shape[0]
    if out:
        avg = runs / out
    else:
        avg = np.inf

    nballs = df[~(df.extra_type == 'wides')].shape[0]
    if nballs:
        strike_rate = runs / nballs * 100
    else:
        strike_rate = 0
    gb = df.groupby('ID').sum()
    fifties = gb[(gb.batsman_run >= 50) & (gb.batsman_run < 100)].shape[0]
    hundreds = gb[gb.batsman_run >= 100].shape[0]
    try:
        highest_score = gb.batsman_run.max()
        hsindex = gb.batsman_run.idxmax()
        if (df[df.ID == hsindex].player_out == batsman).any():
            highest_score = str(highest_score)
        else:
            highest_score = str(highest_score) + '*'
    except:
        highest_score = gb.batsman_run.max()

    not_out = inngs - out
    mom = df[df.Player_of_Match == batsman].drop_duplicates('ID', keep='first').shape[0]
    data = {
        'innings': inngs,
        'runs': runs,
        'fours': fours,
        'sixes': sixes,
        'avg': avg,
        'strikeRate': strike_rate,
        'fifties': fifties,
        'hundreds': hundreds,
        'highestScore': highest_score,
        'notOut': not_out,
        'mom': mom
    }
    return data


# Call the function and print the result for a specific batsman
batsman_name = 'V Kohli'  # Replace with the desired batsman's name
result = batsmanAPI(batsman_name, matches, batter_data)
print(result)
# Out:
# <ipython-input-362-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-362-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-362-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# ...

# %%
import pandas as pd
import numpy as np
import json

# Merge ball and match data
ball_withmatch = balls.merge(matches, on='ID', how='inner').copy()
ball_withmatch['BowlingTeam'] = ball_withmatch.Team1 + ball_withmatch.Team2
ball_withmatch['BowlingTeam'] = ball_withmatch[['BowlingTeam', 'BattingTeam']].apply(lambda x: x.values[0].replace(x.values[1], ''), axis=1)
batter_data = ball_withmatch[np.append(balls.columns.values, ['BowlingTeam', 'Player_of_Match'])]

# Read the CSV files
matches = pd.read_csv('/content/ipl-matches.csv')
balls = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022 - IPL_Ball_by_Ball_2008_2022.csv')

class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

def batsmanRecord(batsman, df):
    if df.empty:
        return np.nan
    out = df[df.player_out == batsman].shape[0]
    df = df[df['batter'] == batsman]
    inngs = df.ID.nunique()
    runs = df.batsman_run.sum()
    fours = df[(df.batsman_run == 4) & (df.non_boundary == 0)].shape[0]
    sixes = df[(df.batsman_run == 6) & (df.non_boundary == 0)].shape[0]
    if out:
        avg = runs / out
    else:
        avg = np.inf

    nballs = df[~(df.extra_type == 'wides')].shape[0]
    if nballs:
        strike_rate = runs / nballs * 100
    else:
        strike_rate = 0
    gb = df.groupby('ID').sum()
    fifties = gb[(gb.batsman_run >= 50) & (gb.batsman_run < 100)].shape[0]
    hundreds = gb[gb.batsman_run >= 100].shape[0]
    try:
        highest_score = gb.batsman_run.max()
        hsindex = gb.batsman_run.idxmax()
        if (df[df.ID == hsindex].player_out == batsman).any():
            highest_score = str(highest_score)
        else:
            highest_score = str(highest_score) + '*'
    except:
        highest_score = gb.batsman_run.max()

    not_out = inngs - out
    mom = df[df.Player_of_Match == batsman].drop_duplicates('ID', keep='first').shape[0]
    data = {
        'innings': inngs,
        'runs': runs,
        'fours': fours,
        'sixes': sixes,
        'avg': avg,
        'strikeRate': strike_rate,
        'fifties': fifties,
        'hundreds': hundreds,
        'highestScore': highest_score,
        'notOut': not_out,
        'mom': mom
    }
    return data


def batsmanVsTeam(batsman, team, df):
    df = df[df.BowlingTeam == team].copy()
    return batsmanRecord(batsman, df)

def batsmanAPI(batsman, matches, balls):
    df = balls[balls.innings.isin([1, 2])]  # Excluding Super overs
    self_record = batsmanRecord(batsman, df=df)
    TEAMS = matches.Team1.unique()
    against = {team: batsmanVsTeam(batsman, team, df) for team in TEAMS}
    data = {
        batsman: {'all': self_record,
                  'against': against}
    }
    return json.dumps(data, cls=NpEncoder)



# Call the function and print the result for a specific batsman
batsman_name = 'V Kohli'  # Replace with the desired batsman's name
result = batsmanAPI(batsman_name, matches, batter_data)
print(result)
# Out:
# <ipython-input-363-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-363-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-363-a1bec641780b>:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# ...

# %%
def batsmanRecord(batsman, df):
    if df.empty:
        return np.nan
    out = df[df.player_out == batsman].shape[0]
    df = df[df['batter'] == batsman]
    inngs = df.ID.unique().shape[0]
    runs = df.batsman_run.sum()
    fours = df[(df.batsman_run == 4) & (df.non_boundary == 0)].shape[0]
    sixes = df[(df.batsman_run == 6) & (df.non_boundary == 0)].shape[0]
    if out:
        avg = runs / out
    else:
        avg = np.inf

    nballs = df[~(df.extra_type == 'wides')].shape[0]
    if nballs:
        strike_rate = runs / nballs * 100
    else:
        strike_rate = 0
    gb = df.groupby('ID').sum()
    fifties = gb[(gb.batsman_run >= 50) & (gb.batsman_run < 100)].shape[0]
    hundreds = gb[gb.batsman_run >= 100].shape[0]
    try:
        highest_score = gb.batsman_run.sort_values(ascending=False).head(1).values[0]
        hsindex = gb.batsman_run.sort_values(ascending=False).head(1).index[0]
        if (df[df.ID == hsindex].player_out == batsman).any():
            highest_score = str(highest_score)
        else:
            highest_score = str(highest_score) + '*'
    except:
        highest_score = gb.batsman_run.max()

    not_out = inngs - out
    mom = df[df.Player_of_Match == batsman].drop_duplicates('ID', keep='first').shape[0]
    data = {
        'innings': inngs,
        'runs': runs,
        'fours': fours,
        'sixes': sixes,
        'avg': avg,
        'strikeRate': strike_rate,
        'fifties': fifties,
        'hundreds': hundreds,
        'highestScore': highest_score,
        'notOut': not_out,
        'mom': mom
    }

    return data


def batsmanVsTeam(batsman, team, df):
    df = df[df.BowlingTeam == team].copy()
    return batsmanRecord(batsman, df)


def batsmanAPI(batsman, balls=batter_data):
    df = balls[balls.innings.isin([1, 2])]  # Excluding Super overs
    self_record = batsmanRecord(batsman, df=df)
    TEAMS = matches.Team1.unique()
    against = {team: batsmanVsTeam(batsman, team, df) for team in TEAMS}
    data = {
        batsman: {'all': self_record,
                  'against': against}
    }
    return json.dumps(data, cls=NpEncoder)

bowler_data = batter_data.copy()

# %%
batsmanAPI('V Kohli')
# Out:
# <ipython-input-364-3ab6cb8aef0d>:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-364-3ab6cb8aef0d>:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-364-3ab6cb8aef0d>:20: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# ...

# %%
ipl_matches = 'ipl-matches.csv'
matches = pd.read_csv(ipl_matches)
ipl_ball = 'IPL_Ball_by_Ball_2008_2022 - IPL_Ball_by_Ball_2008_2022.csv'
balls = pd.read_csv(ipl_ball)
ball_withmatch = balls.merge(matches, on='ID', how='inner').copy()
ball_withmatch['BowlingTeam'] = ball_withmatch.Team1 + ball_withmatch.Team2
ball_withmatch['BowlingTeam'] = ball_withmatch[['BowlingTeam', 'BattingTeam']].apply(
    lambda x: x.values[0].replace(x.values[1], ''), axis=1)
batter_data = ball_withmatch[np.append(balls.columns.values, ['BowlingTeam', 'Player_of_Match'])]
bowler_data = batter_data.copy()


def bowlerRun(x):
    if x[0] in ['penalty', 'legbyes', 'byes']:
        return 0
    else:
        return x[1]


bowler_data['bowler_run'] = bowler_data[['extra_type', 'total_run']].apply(bowlerRun, axis=1)


def bowlerWicket(x):
    if x[0] in ['caught', 'caught and bowled', 'bowled', 'stumped', 'lbw', 'hit wicket']:
        return x[1]
    else:
        return 0


bowler_data['isBowlerWicket'] = bowler_data[['kind', 'isWicketDelivery']].apply(bowlerWicket, axis=1)


def bowlerRecord(bowler, df):
    # if df.empty:
    # return np.nan

    df = df[df['bowler'] == bowler]
    inngs = df.ID.unique().shape[0]
    nballs = df[~(df.extra_type.isin(['wides', 'noballs']))].shape[0]
    runs = df['bowler_run'].sum()
    if nballs:
        eco = runs / nballs * 6
    else:
        eco = 0
    fours = df[(df.batsman_run == 4) & (df.non_boundary == 0)].shape[0]
    sixes = df[(df.batsman_run == 6) & (df.non_boundary == 0)].shape[0]

    wicket = df.isBowlerWicket.sum()
    if wicket:
        avg = runs / wicket
    else:
        avg = np.inf

    if wicket:
        strike_rate = nballs / wicket * 100
    else:
        strike_rate = np.nan

    gb = df.groupby('ID').sum()
    w3 = gb[(gb.isBowlerWicket >= 3)].shape[0]

    best_wicket = gb.sort_values(['isBowlerWicket', 'bowler_run'], ascending=[False, True])[
        ['isBowlerWicket', 'bowler_run']].head(1).values
    if best_wicket.size > 0:

        best_figure = f'{best_wicket[0][0]}/{best_wicket[0][1]}'
    else:
        best_figure = np.nan
    mom = df[df.Player_of_Match == bowler].drop_duplicates('ID', keep='first').shape[0]
    data = {
        'innings': inngs,
        'wicket': wicket,
        'economy': eco,
        'average': avg,
        'avg': avg,
        'strikeRate': strike_rate,
        'fours': fours,
        'sixes': sixes,
        'best_figure': best_figure,
        '3+W': w3,
        'mom': mom
    }

    return data


def bowlerVsTeam(bowler, team, df):
    df = df[df.BattingTeam == team].copy()
    return bowlerRecord(bowler, df)


def bowlerAPI(bowler, balls=bowler_data):
    df = balls[balls.innings.isin([1, 2])]  # Excluding Super overs
    self_record = bowlerRecord(bowler, df=df)
    TEAMS = matches.Team1.unique()
    against = {team: bowlerVsTeam(bowler, team, df) for team in TEAMS}
    data = {
        bowler: {'all': self_record,
                 'against': against}
    }
    return json.dumps(data, cls=NpEncoder)

# %%
bowlerAPI('B Kumar')
# Out:
# <ipython-input-366-440b782c8244>:59: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-366-440b782c8244>:59: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# <ipython-input-366-440b782c8244>:59: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gb = df.groupby('ID').sum()
# ...

# %%
matches = pd.read_csv('/content/ipl-matches.csv')

# %%
matches.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
matches['TossDecision'].value_counts()
# Out:
# field    599
# bat      351
# Name: TossDecision, dtype: int64

# %%
city_counts = matches['Venue'].value_counts()
index_list = list(city_counts.index)

# %%
df = matches[matches['City'] == 'Ahmedabad']
total_matches = df['ID'].value_counts().sum()
toss = df['TossDecision'].value_counts()
win_loss = df['WonBy'].value_counts()
# Out:
# 19

# %%
balls = pd.read_csv('/content/IPL_Ball_by_Ball_2008_2022 - IPL_Ball_by_Ball_2008_2022.csv')

# %%
balls.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
def toss_related_info():
    matches['TossDecision'].value_counts()
    matches['WonBy'].value_counts()
    matches['Player_of_Match'].value_counts()
    matches['City'].value_counts()

# %%
def stadium_related_info():
    venue_counts = matches['Venue'].value_counts()
    index_list = list(venue_counts.index)

    stadium_info = {}

    for venue in index_list:
        df = matches[matches['Venue'] == venue]
        df_merged = pd.merge(df, balls, left_on='ID', right_on='ID', how='left')

        total_matches = df.shape[0]
        toss = df['TossDecision'].value_counts().to_dict()
        win_loss = df['WinningTeam'].value_counts().to_dict()

        average_runs = (df_merged['total_run']).mean()

        batting_avg = df_merged.groupby(['batter'])['batsman_run'].mean().to_dict()
        bowling_avg = df_merged.groupby(['bowler'])['batsman_run'].mean().to_dict()
        common_result = df['Match_Result'].mode().iloc[0]

        highest_run_scorer = df_merged.loc[df_merged['batsman_run'].idxmax(), 'batter']
        highest_wicket_taker = df_merged.loc[df_merged['isWicketDelivery'].idxmax(), 'bowler']

        df_merged['Margin'] = abs(df_merged['batsman_run'] - df_merged['total_run'])
        closest_match = df_merged.loc[df_merged['Margin'].idxmin()]

        res = {
            'total_matches': total_matches,
            'toss_win_loss': toss,
            'win_loss': win_loss,
            'average_runs': average_runs,
            'batting_avg': batting_avg,
            'bowling_avg': bowling_avg,
            'common_result': common_result,
            'highest_run_scorer': highest_run_scorer,
            'highest_wicket_taker': highest_wicket_taker,
            'closest_match': closest_match.to_dict()
        }

        stadium_info[venue] = res

    return stadium_info

# %%
stadium_related_info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Match_Result'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def stadium_related_info():
    venue_counts = matches['Venue'].value_counts()
    index_list = list(venue_counts.index)

    stadium_info = {}

    for venue in index_list:
        df = matches[matches['Venue'] == venue]
        total_matches = df.shape[0]
        toss = df['TossDecision'].value_counts()
        win_loss = df['WonBy'].value_counts()

        res = {
            'total_matches': total_matches,
            'toss_win_loss': toss.to_dict(),
            'win_loss': win_loss.to_dict()
        }

        stadium_info[venue] = res

    return stadium_info

# %%
stadium_related_info()
# Out:
# {'Eden Gardens': {'total_matches': 77,
#   'toss_win_loss': {'field': 49, 'bat': 28},
#   'win_loss': {'Wickets': 45, 'Runs': 32}},
#  'Wankhede Stadium': {'total_matches': 73,
#   'toss_win_loss': {'field': 51, 'bat': 22},
#   'win_loss': {'Wickets': 37, 'Runs': 35, 'SuperOver': 1}},
#  'M Chinnaswamy Stadium': {'total_matches': 65,
#   'toss_win_loss': {'field': 57, 'bat': 8},
#   'win_loss': {'Wickets': 36, 'Runs': 26, 'NoResults': 2, 'SuperOver': 1}},
#  'Feroz Shah Kotla': {'total_matches': 60,
#   'toss_win_loss': {'field': 34, 'bat': 26},
#   'win_loss': {'Wickets': 31, 'Runs': 28, 'NoResults': 1}},
#  'Rajiv Gandhi International Stadium, Uppal': {'total_matches': 49,
#   'toss_win_loss': {'field': 26, 'bat': 23},
#   'win_loss': {'Wickets': 28, 'Runs': 20, 'SuperOver': 1}},
#  'MA Chidambaram Stadium, Chepauk': {'total_matches': 48,
#   'toss_win_loss': {'bat': 34, 'field': 14},
#   'win_loss': {'Runs': 30, 'Wickets': 17, 'SuperOver': 1}},
# ...
